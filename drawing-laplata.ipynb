# %%
import osmnx as ox
import matplotlib.pyplot as plt

# %%
#cf = '["highway"~"motorway|trunk|primary|secondary|tertiary"]'

# %%
la_plata = ox.graph_from_place('Partido de La Plata, Buenos Aires, Argentina',
                                network_type='drive',
                                simplify=True,
                                #custom_filter=cf
                        )

# %%
fig, ax = ox.plot_graph(la_plata,
                         node_size=0.001, 
                         node_color='r',
                         edge_color='w',
                         edge_linewidth=0.2
                         )
